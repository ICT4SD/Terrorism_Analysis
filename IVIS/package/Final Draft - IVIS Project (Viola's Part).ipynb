# %% [markdown]
# # IVIS HeatMap & Geo2D Tests
#
# @Viola, Dec 2016

# %% [markdown]
# ### 1. Data Loading and Processing

# %%
# %matplotlib inline

# %%
from data import *
from heatmap import *
from Geo2D import *
from choropleth import *

# %% [markdown]
# #### The above data processing generates a clean data set named "gtd_wholedata_selected.csv".
# In order to save loading time and storage space, all the following analysis will be based on this data set.

# %%
gt_df = pd.read_csv('gtd_wholedata_selected.csv')

# %% [markdown]
# ### 2. HeatMap

# %%
Display_Your_Heatmap()
# Out:
# <function heatmap.Heatmap_by_region>

# %% [markdown]
# ### 3. Geo2D Map

# %%
Display_Your_Geo2D_Map()
# Out:
# <function Geo2D.plot_2D_density>

# %% [markdown]
# ### 4. Choropleth

# %%
Display_Your_Chorpleth()

# Error Raises when Year == 1993 (No GTD data in 1993!)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
# <function choropleth.plot_choropleth>
