# %% [markdown]
# [![Center for Data Science - New York University](https://raw.githubusercontent.com/violaciao/IVIS-GC/master/Header.png)](https://ict4sd.github.io/2016/11/10/Project_Global_Terror/)
# <span class="caption text-muted">1007 Final Project - by Xianzhi Cao and Caroline Roper - Center for Data Science - New York University</span>

# %% [markdown]
# ## Need to change header's text, include the info like: A joint data analysis project with UN..

# %% [markdown]
# ### - Add pie charts to analyze attack targets and motive

# %%
# %matplotlib inline

# %%
from data import *
from heatmap import *
from Geo2D import *
from choropleth import *
from lineplot import *
from UserError import *

# %% [markdown]
# ### Country Scale Overview

# %%
Display_Your_LinePlot()

# %% [markdown]
# ### HeatMap

# %%
Display_Your_Heatmap()
# Out:
# <function heatmap.Heatmap_by_region>

# %% [markdown]
# ### Geo2D Map

# %%
#Display_Your_Geo2D_Map()

# %% [markdown]
# ### Choropleth

# %%
#Display_Your_Chorpleth()

# Error Raises when Year == 1993 (No GTD data in 1993!)
