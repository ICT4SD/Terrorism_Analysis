# %% [markdown]
# # IVIS

# %% [markdown]
# ### 1. Data Loading and Processing

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os

from ipywidgets import *
from IPython.display import display

from data import *
from feature import *
from heatmap import *

# %%
# excel_to_csv(path_excelfile = '../data/globalterrorismdb_0616dist.xlsx')

# %%
save_df_csv()

# %% [markdown]
# #### The above data processing generates a clean data set named "gtd_wholedata_selected.csv".
# In order to save loading time and storage space, sll the following analysis will be based on this data set.

# %%
gt_df = pd.read_csv('gtd_wholedata_selected.csv')

# %% [markdown]
# ### HeatMap

# %%
interact(Heatmap_by_region, 
         Region=tuple(IVIS().region_names),
         Cmap = (Cmap_palette()),
         Indication = ToggleButtons(options={'Casualties': 'casualties', 'Wounds': 'wounds'},
                         description='Indication', disabled=False, button_style='', tooltip='Description'))
