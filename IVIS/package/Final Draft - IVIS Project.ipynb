# %% [markdown]
# [![Center for Data Science - New York University](https://raw.githubusercontent.com/violaciao/IVIS-GC/master/Header.png)](https://ict4sd.github.io/2016/11/11/Project_Global_Terror/)
# <span class="caption text-muted">  </span>

# %% [markdown]
# <h1 align="center"><font color='yellowgreen'>Welcome to IVIS for Global Terrorism Analysis</font></h1>

# %%
# %matplotlib inline
from IVIS import *

# %% [markdown]
# <h3 align="right"><font color='Medium Sea Green'>[Go To User Manual](https://docs.google.com/document/d/1KNxP-8Ccey1tM1sOBJRB7VyB3rjtPe2gbDFlHtD_iCk/edit?usp=sharing)</font></h3>

# %% [markdown]
# <h2 align="center"><font color='steelblue'>Country Scale Overview</font></h2>

# %%
IVIS_AL()
# Out:
#              Statistical Analysis - Terror Attacks in The Whole World
#                                   * * *
# --+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--
# During the year 1970 to 2015:
#     - The year with the most attacks:        2014.0
#              * 16840 times of terror attacks in The Whole World in this year
#     - The year with the most damages:        2014.0
#              * The Whole World suffered the most severe damage by terrorism in this year.
#              * 84089 people were killed or wounded.
#              * 16840 times of terror attacks in The Whole World in this year
#     - Occurrence of Terror Attacks
#              * The total number:              156772
#              * The annual average:            3483
#              * The standard deviation:        3441.55354249
#     - Casualties
#          1) The total number:                 788217
#              * kills                          348215
# ...

# %% [markdown]
# <h1 align="center"><font color='skyblue'>==============================================================</font></h1>

# %% [markdown]
# <h1 align="center"><font color='steelblue'>Choropleth</font></h1>

# %%
IVIS_CHR()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# <h1 align="center"><font color='skyblue'>==============================================================</font></h1>

# %% [markdown]
# <h1 align="center"><font color='steelblue'>Bubble Chart</font></h1>

# %%
IVIS_BC()

# %% [markdown]
# <h1 align="center"><font color='skyblue'>==============================================================</font></h1>

# %% [markdown]
# <h1 align="center"><font color='steelblue'>HeatMap</font></h1>

# %%
IVIS_HT()

# %% [markdown]
# <h1 align="center"><font color='skyblue'>==============================================================</font></h1>

# %% [markdown]
# <h1 align="center"><font color='steelblue'>Geo2D Map</font></h1>

# %%
IVIS_GEO()

# %% [markdown]
# [![ICT4SD supports the Sustainable Development Goals.](https://ict4sd.github.io/img/E_Logo_No%20UN%20Emblem-01.png)](https://ict4sd.github.io/2016/11/11/Project_Global_Terror/)
# <span class="caption text-muted"> </span>

# %% [markdown]
# <h3 align="center"><font color='skyblue'>Thank you for your experience.</font></h3>
# <h3 align="center"><font color='skyblue'>Please let us know what you think. We'd love to hear it.</font></h3>
# <h4 align="center"><font color='darkgrey'>Viola & Caroliner</font></h4>

# %% [markdown]
# <div class="container">
#         <div class="row">
#             <div class="col-lg-4 col-lg-offset-3 col-md-1 col-md-offset-1">
#                 <ul class="list-inline text-center">
#                     <li>
#                         <a href="https://www.facebook.com/viola.x.ciao">
#                             <span class="fa-stack fa-lg">
#                                 <i class="fa fa-circle fa-stack-2x"></i>
#                                 <i class="fa fa-facebook fa-stack-1x fa-inverse"></i>
#                             </span>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://github.com/violaciao">
#                             <span class="fa-stack fa-lg">
#                                 <i class="fa fa-circle fa-stack-2x"></i>
#                                 <i class="fa fa-github fa-stack-1x fa-inverse"></i>
#                             </span>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="mailto:xianzhi.cao@nyu.edu">
#                             <span class="fa-stack fa-lg">
#                                 <i class="fa fa-circle fa-stack-2x"></i>
#                                 <i class="fa fa-envelope fa-stack-1x fa-inverse"></i>
#                             </span>
#                         </a>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </div>

# %% [markdown]
# ###
